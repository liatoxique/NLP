# %% [markdown]
# Определение языка (language detection)
# --------------------
#
# Александра Степанова. БКЛ-151

# %% [markdown]
# ### Первый метод: частотные слова

# %% [markdown]
# #### Скачаем немного википедии для тестов
# Воспользуемся пакетом *wikipedia*:
#
# `pip install wikipedia`

# %%
import wikipedia
import codecs
import collections
import sys
import re

# %% [markdown]
# Возьмем французский, исландский, шведский и литовский языки.

# %%
langs = ('fr', 'is', 'sv', 'lt')

# %%
def get_texts_for_lang(lang, n=10): # функция для скачивания статей из википедии
    wikipedia.set_lang(lang)
    wiki_content = []
    pages = wikipedia.random(n)
    for page_name in pages:
        try:
            page = wikipedia.page(page_name)
        except wikipedia.exceptions.WikipediaException:
            print('Skipping page {}'.format(page_name))
            continue

        wiki_content.append('{}\n{}'.format(page.title, page.content.replace('==', '')))

    return wiki_content

# %%
wiki_texts = {}
for lang in langs: 
    wiki_texts[lang] = get_texts_for_lang(lang, 100)
    print(lang, len(wiki_texts[lang]))
# Out:
# c:\users\user\appdata\local\programs\python\python35-32\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file c:\users\user\appdata\local\programs\python\python35-32\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Skipping page Trastos (homonymie)
# Skipping page Jamie Smith (football)
# Skipping page Danny Watts
# Skipping page Sadievo
# Skipping page Au Petit Paris
# fr 95
# Skipping page Örn
# Skipping page Hnakki
# Skipping page Línuskip
# is 97
# Skipping page Shortys Island
# Skipping page Sochiapa
# Skipping page Darah-ye Shākh-e Safēd
# Skipping page Collins Hill
# Skipping page Déré (vattendrag i Centralafrikanska republiken, lat 5,55, long 16,39)
# Skipping page Sungai Bunut
# Skipping page Vincenzo Montefusco
# Skipping page Laguna El Chino
# Skipping page Kasuni
# Skipping page Isoluoto (del av en ö)
# Skipping page Roß Kopf
# sv 89
# Skipping page Gaižiūnų apylinkė
# Skipping page Rimšelis
# Skipping page Levinas
# Skipping page Ptakai (reikšmės)
# Skipping page Girdauskas
# Skipping page Santa Krusas
# Skipping page Solnikai (reikšmės)
# lt 93

# %%
print(wiki_texts['is'][0]) # распечатаем пару текстов, чтобы убедиться, что все хорошо
print(wiki_texts['sv'][0])
# Out:
# Laddi
# Þórhallur Sigurðsson (fæddur 20. janúar 1947), best þekktur sem Laddi, er íslenskur leikari, söngvari, tónskáld og skemmtikraftur. Hann hefur gefið út plötur, leikið í kvikmyndum og tekið þátt í miklum fjölda skemmtiþátta sem handritshöfundur og leikari, t.d Heilsubælinu, Imbakassanum og Spaugstofunni Einnig hefur hann leikið í mörgum Áramótaskaupum og tekið þátt í að semja þau. Hann hefur skapað fjöldann allan af karakterum sem margir kannast við og nægir að nefna Eirík Fjalar, Saxa lækni, Skúla rafvirkja, Magnús bónda, Ho Si Mattana, Elsu Lund, Martein Mosdal og svo mætti lengi telja. Kvikmyndir sem hann hefur leikið í eru t.d Stella í orlofi, Stella í framboði, Magnús, Regína, Íslenski draumurinn, Jóhannes, Ófeigur gengur aftur og fleiri. Einnig hefur hann starfað mikið í leikhúsi, en frægustu hlutverk hans á þeim vettvangi eru líklega Fagin í Óliver Twist og Tannlækninn í Litlu Hryllingsbúðinni.
# Laddi var í tvíeykinu Halli og Laddi ásamt bróður sínum Haraldi Sigurðssyni. Þeir bræður nutu gríðarlegra vinsælda á áttunda áratug síðustu aldar, þóttu ómissandi í skemmtiþáttum í sjónvarpi og gáfu út nokkrar hljómplötur með tónlist og gamanmálum. Þekktasta plata þeirra er líklega "Látum eins og ekkert C", sem þeir gerðu ásamt Gísla Rúnari Jónssyni.
# Laddi hóf tónlistarferil sinn sem trommari í hljómsveitinni "Föxum". Í seinni tíð hefur hann samið fjölda laga og mörg þeirra hafa náð vinsældum, t.d. Sandalar, Austurstræti og Búkolla, en útgefin lög hans og textar skipta tugum. Hann starfaði um tíma með hljómsveitinni "Brunaliðinu", en mest af tónlistarefni hans hefur komið út á sólóplötum eins og "Einn voða vitlaus" og "Deijó", auk þess sem það er að finna á fjölmörgum safnplötum.
# Á níunda áratugnum stofnuðu Halli og Laddi HLH flokkinn ásamt Björgvini Halldórssyni. Flokkurinn stældi útlit og tónlistarstíl rokktímans milli 1950 og '60 og átti nokkra sívinsæla smelli eins og "Riddari götunnar", "Seðill" og "Í útvarpinu heyrði lag".
# Laddi tók þátt í stofnun Spaugstofunnar 1985 og starfaði með þeim hóp fyrstu árin. Hann hefur einnig skotið upp kollinum í þáttum Spaugstofunnar í seinni tíð, oftast sem gestaleikari, en veturinn 2013-'14 tók hann þátt í heilli þáttaröð á Stöð 2. Hann hefur talsett mikinn fjöld teiknimynda og kvikmynda og má þar nefna Aladdin, Konung ljónanna, Mulan, Wreck it Ralph, Frosinn, Brakúla og margar fleiri. Þó var það ef til vill eftirtektarverðast þegar hann talsetti allar teiknimyndirnar um Strumpana einn síns liðs.
# Laddi á þrjá syni: Martein, Ívar og Þórhall, sem vann keppnina "Fyndnasti maður Íslands" árið 2007.
# Árið 2007 setti Laddi upp sýninguna "Laddi 6-tugur" í Borgarleikhúsinu til að fagna sextugsafmæli sínu.
# Í byrjun áttu þetta bara að vera 4 sýningar en vegna gríðarlegrar aðsóknar varð sýningin ein vinsælasta grínsýning sem sett hefur verið upp á Íslandi. Sex árum síðar kom upp sýningin "Laddi lengir lífið" í Hörpu. Þar sló Laddi enn á nýja strengi, afhjúpaði sjálfan sig og fortíð sína og leyfði áhorfendum að skyggnast inn í sálarlíf mannsins sem hafði skemmt þeim svo vel í öll þessi ár.
#
#
#  Tenglar
# Laddi á Internet Movie Database
# IG Markets
# IG Markets är ett företag som specialiserar sig på finansiella derivatinstrument, huvudsakligen handel med CFD (Contract for difference) på aktier, index, råvaror och valutor. Företaget är en del av det i London börsnoterade IG Group som ingår i FTSE 250 Index.
# Företagets huvudkontor ligger i London. Kontor finns också i Stockholm (Stureplan), Düsseldorf, Paris, Luxemburg, Lissabon, Milano, Madrid, Singapore, Tokyo, Melbourne och Chicago.
# IG Markets Limited står under tillsyn av Financial Services Authority (den brittiska finansinspektionen) och har FSA-registreringsnummer 195355. Företagets filial i Sverige är registrerat av Finansinspektionen.
# IG Markets kunder utgörs av privata investerare, aktiemäklare och fondförvaltare. Cirka 99 procent av kundernas transaktioner sker online.
#
#
#  Referenser
# Företagets webbplats

# %% [markdown]
# Чистим тексты от всех небуквенных единиц.

# %%
def tokenize(text):
    pattern = re.compile('[\.,\-\`\#\?\+\*\^\d\=\~\!\@\$\%\&\(\)\_\—\[\]\{\}\:\;\'\"\/\\\>\<\|„“]')
    text = pattern.sub(' ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.split(' ')

# %% [markdown]
# Создаем словарь, в котором будут храниться все частотные списки. Сначала создаем частотные сеты для каждого языка, избавляемся от пересечений, после чего помещаем их в словарь, который и будет использовать для определения языка.

# %%
def make_freq(lang, wiki_texts):
    freq_lang = collections.defaultdict(lambda: 0)
    corpus = wiki_texts[lang]
    for article in corpus:
        for word in tokenize(article.replace('\n', '').lower()):
            freq_lang[word] += 1
    return set(freq_lang.keys())

# %%
is_set = make_freq('is', wiki_texts)
fr_set = make_freq('fr', wiki_texts)
sv_set = make_freq('sv', wiki_texts)
lt_set = make_freq('lt', wiki_texts)

# %%
duplicates = set.intersection(is_set, fr_set, sv_set, lt_set)

# %%
is_set = is_set - duplicates
fr_set = fr_set - duplicates
sv_set = sv_set - duplicates
lt_set = lt_set - duplicates

# %%
lt_set
# Out:
# {'fildingas',
#  'mokslų',
#  'elektrinio',
#  'stilių',
#  'kitos',
#  'kidulių',
#  'petrosianą',
#  'stogas',
#  'turkiją',
#  'van',
#  'užsibuvusi',
#  'kelerius',
#  'masės',
#  'bėgdamas',
#  'buen',
#  'aplaistytas',
#  'manila',
#  'nerija',
#  'galvojamas',
#  'grupėmis',
#  'lobio',
#  'šilalės',
#  'tepirmavo',
#  'pastatų',
#  'buožių',
#  'pilotas',
#  'einantis',
#  'verakruso',
#  'hobitai',
#  'teritorijų',
#  'dardanelių',
#  'miliamperų',
#  'vietose',
#  'kovą',
#  'operos',
#  'pilnas',
#  'pasiruošė',
#  'kelis',
#  'skaidrus',
#  'vaidmenis',
#  'raštų',
#  'elijadė',
#  'dobšina',
#  'privalomas',
#  'gajumą',
#  'švedijoje',
#  'botviniku',
#  'ტბა',
#  'fakultetų',
#  'ko',
#  'praktikuotas',
#  'turnyras',
#  'kretingos',
#  'viename',
#  'kitaip',
#  'nešė',
#  'strategines',
#  'darbai',
#  'chelsea',
#  'smarkiai',
#  'kitų',
#  'geografas',
#  'paieška',
#  'automobilis',
#  'keturiolika',
#  'pati',
#  'laimę…',
#  'veikloje',
#  'dauguma',
#  'valdžia',
#  'įsiviešpatavo',
#  'fabriką',
#  'sugihara',
#  'nusipelniusio',
#  'elektrėnų',
#  'vokietija',
#  'suvienijo',
#  'songo',
#  'mokslo',
#  'raj',
#  'planktonu',
#  'leonidas',
#  'europoje',
#  'padaliname',
#  'pradinio',
#  'karpovo',
#  'kaire',
#  'koplyčia',
#  'kaukėmis',
#  'patogaus',
#  'jabiru',
#  'išraiška',
#  'atramos',
#  'padalintas',
#  'griovį',
#  'eilę',
#  'kunigaikštystė',
#  'surašymai',
#  'dnepro',
#  'smith',
#  'lučiana',
#  'afzelia',
#  'ligtol',
#  'kabardos',
#  'tokia',
#  'nachičevanės',
#  'diemedis',
#  'švėgžda',
#  'alkos',
#  'kvalifikaciją',
#  'tinklalapis',
#  'čėsna',
#  'viesgirdžių',
#  'įvesta',
#  'brešos',
#  'nuorodas',
#  'perversmų',
#  'vaidas',
#  'pakalniuose',
#  'laikams',
#  'dydžiu',
#  'rungtyje',
#  'pastarasis',
#  'diana',
#  'šalimais',
#  'laukuose',
#  'castanopsis',
#  'žemdirbyste',
#  'kito',
#  'olimpinis',
#  'pertvarkyta',
#  'kalbama',
#  'laišką',
#  'teisynui',
#  'kramas',
#  'ištremtas',
#  'kine',
#  'kopia',
#  'visžalis',
#  'nuostatus',
#  'budinti',
#  'didžiausi',
#  'nebepasirodys',
#  'naumiestis–šakiai',
#  'bandoma',
#  'politiko',
#  'archeologijos',
#  'didžiąją',
#  'dievaitytės',
#  'muzeologijos',
#  'shigenobu',
#  'luomus',
#  'juose',
#  'młoda',
#  'darbuotojai',
#  'tvarkos',
#  'apdovanotas',
#  'dalyvauja',
#  'veiklą',
#  'jasuose',
#  'archeologai',
#  'vadimas',
#  'baltieji',
#  'pirmininko',
#  'maiklas',
#  'artefaktus',
#  'dėjosi',
#  'lenkų',
#  'sádão',
#  'garbei',
#  'danų',
#  'dviejų',
#  'ūkių',
#  'eksčempionas',
#  'įsukama',
#  'nuostatai',
#  'aprašas',
#  'rūšių',
#  'halicki',
#  'žinduoliais',
#  'žurnalo',
#  'varšuva',
#  'uostuose',
#  'chomskis',
#  'nežinojau',
#  'vienokios',
#  'mlodajakač',
#  'socialinę',
#  'tradicija',
#  'trėmimai',
#  'aparatas',
#  'savarankiško',
#  'forumo',
#  'stenbekas',
#  'valjenaro',
#  'duomenis',
#  'darė',
#  'augustów',
#  'plėtra',
#  'holsatus',
#  'egipte',
#  'gandrinių',
#  'sukurtoji',
#  'laidotuvėse',
#  'pranašai',
#  'pertvarkė',
#  'pasirašyta',
#  'artūras',
#  'fišeriu',
#  'taškus',
#  'apnašomis',
#  'emocijų',
#  'imitacijos',
#  'sutriuškino',
#  'turtingi',
#  'loreta',
#  'proftechnikos',
#  'partiniai',
#  'europos',
#  'pavelas',
#  'kūno',
#  'vėl',
#  'gymnast',
#  'revoliucionierius',
#  'skaičų',
#  'repertuare',
#  'atgimimui',
#  'sparnuočiai',
#  'aukščiausio',
#  'baltaisiais',
#  'kiršų',
#  'biologas',
#  'viziją',
#  'ekspansiją',
#  'georgiu',
#  'kitas',
#  'makowski',
#  'vaidinamas',
#  'бурабай',
#  'atsilikimo',
#  'skaitė',
#  'velingtonas',
#  'beviltišką',
#  'florinas',
#  'savitą',
#  'patys',
#  'registras',
#  'hobiu',
#  'atributų',
#  'pedagogė',
#  'aukštų',
#  'mechanika',
#  'stebėseną',
#  'sprendimu',
#  'hondžo',
#  'esant',
#  'pradėtas',
#  'savo',
#  'jenson',
#  'geografijos',
#  'priešpiliu',
#  'paprastai',
#  'muravjovas',
#  'vašingtonas',
#  'bažnyčiai',
#  'svetainėtailando',
#  'sutelkė',
#  'x',
#  'bucharinas',
#  'megalaima',
#  'grandinėje',
#  'ūkio',
#  'filmui',
#  'persvara',
#  'apskrityse',
#  'vestgotų',
#  'okeris',
#  'beržinis',
#  'geologijos',
#  'garbės',
#  'picasaweb',
#  'gindama',
#  'sukurtas',
#  'siamensis',
#  'pagaliau',
#  'krašte',
#  'absoliutizmo',
#  'kviestas',
#  'padalintos',
#  'įsitvirtinusi',
#  'turnyruose',
#  'noda',
#  'beveik',
#  'v',
#  'ginklai',
#  'velasquez',
#  'prancūzijoje',
#  'alberto',
#  '′',
#  'tan',
#  'struktūra',
#  'takeo',
#  'mitų',
#  'irpurino',
#  'aktorius',
#  'statulėlę',
#  'gimęs',
#  'imperijoje',
#  'perskaityti',
#  'dendrė',
#  'gimtadieniai',
#  'devynis',
#  'antroji',
#  'larpg',
#  'kvinterosas',
#  'toliau',
#  'dabar',
#  'magny',
#  'donnellybill',
#  'pasuka',
#  'straipsnį',
#  'turtinis',
#  'hypsipetes',
#  'interesams',
#  'lėšas',
#  'keturias',
#  'ministrų',
#  'atkakliai',
#  'stuobrių',
#  'augustavo',
#  'aukštumoje',
#  'sykasežerinis',
#  'šventųjų',
#  'karinis',
#  'live',
#  'vladas',
#  'sistemų',
#  'eigminas',
#  'stokholme',
#  'žemėlapio',
#  'druskininkuose',
#  'sąjungoje',
#  'naudojimo',
#  'ništato',
#  'priešistorės',
#  'armiją',
#  'atlanto',
#  'nuotrauka',
#  'jūroje',
#  'administracinis',
#  'kaštelionas',
#  'diplomą',
#  'lėtaslinkis',
#  'daug',
#  'vienaip',
#  'šito',
#  'dešimtmečio',
#  'varžovas',
#  'tikėjosi',
#  'nuosekliai',
#  'europa',
#  'žaidime',
#  'stažavosi',
#  'sąrašai',
#  'atėjo',
#  'atspindėjo',
#  'vardą',
#  'komunikacijos',
#  'vadovauti',
#  'netikri',
#  'įvykdyti',
#  'liberalių',
#  'kostas',
#  'pietvakarių',
#  'šiame',
#  '−',
#  'iškilusiomis',
#  'džilio',
#  'varžovui',
#  'haliucinogeninio',
#  'merasiccho',
#  'išrastas',
#  'gerbėja',
#  'teismų',
#  'albertas',
#  'mokyklą',
#  'panaikinti',
#  'turėjusiems',
#  'energetikas',
#  'mergina',
#  'reikšme',
#  'suaugusios',
#  'mano',
#  'stanislovas',
#  'šventyklą',
#  'amperu',
#  'kanceliarijos',
#  'žemėlapiailankytinos',
#  'gruntinio',
#  'didžiausių',
#  'betrūko',
#  'elkio',
#  'nuosėdinę',
#  'atlieka',
#  'pasibaisėtinas',
#  'nuožiūra',
#  'vadindavo',
#  'zarasų',
#  'kandidatūros',
#  'vakarinės',
#  'japonija',
#  'josifas',
#  'revoliucinis',
#  'lankytinos',
#  'auka',
#  'vera',
#  'venta',
#  'pragręžė',
#  'aukštumos',
#  'norėjo',
#  'propagandinę',
#  'ikiromėniškais',
#  'pasibaisėtinos',
#  'epitetų',
#  'maldos',
#  'žinia',
#  'parkai',
#  'atvejis',
#  'pergalingą',
#  'kučiūnasir',
#  'levir',
#  'pripažinti',
#  'stipris',
#  'itoh',
#  'skien',
#  'chorvedžių',
#  'dalyvauti',
#  'kamergeris',
#  'reiktų',
#  'ketvirtfinalio',
#  'skausmu',
#  'giliame',
#  'ekspansionistinė',
#  'paimti',
#  'bajorija',
#  'paaukotų',
#  'pranc',
#  'balandžio',
#  'absolventai',
#  'leite',
#  'išvengdavo',
#  'pietryčių',
#  'luomą',
#  'unesco',
#  'edukacinės',
#  'lietuvojesuodžių',
#  'sutartis',
#  'ispanijos',
#  'kainardžios',
#  'rica',
#  'nepaskyręs',
#  'honda',
#  'kūnas',
#  'lokys',
#  'diduomenės',
#  'gėlaitį',
#  'smyslovas',
#  'vanduo',
#  'miestiečiai',
#  'tautosakos',
#  'prieigas',
#  'prisijungti',
#  'operatyvinis',
#  'koja',
#  'kyšulys',
#  'vicepremjeras',
#  'finaliniame',
#  'metė',
#  'baigė',
#  'sekančiąją',
#  'baltrūnas',
#  'paviršių',
#  'čempionate',
#  'karolis',
#  'leniją',
#  'russiataurės',
#  'kovų',
#  'flora',
#  'prasimaitina',
#  'juodos',
#  'neįsivaizdavau',
#  'viktoro',
#  'dvejus',
#  'ulua',
#  'vedėja',
#  'išorinis',
#  'juodakaklis',
#  'ribojasi',
#  'milvyduose',
#  'mirtys',
#  'kęstutis',
#  'atstovų',
#  'kanibalu',
#  'inkviziciją',
#  'rūmai',
#  'pagrindinio',
#  'deguonis',
#  'gynyboje',
#  'poligonas',
#  'koplyčią',
#  'žydų',
#  'paminėjimasregėjimų',
#  'grožį',
#  'patikrinti',
#  'kaišiadorių',
#  'sutrikimų',
#  'srityse',
#  'ūsys',
#  'visus',
#  'siekė',
#  'stalo',
#  'vanagaitis',
#  'nesusidorojo',
#  'krepšininkas',
#  'keturnaujienoje',
#  'hožos',
#  'aukštieji',
#  'prasideda',
#  'skelbėsi',
#  'roticko',
#  'historyczna',
#  'mirča',
#  'nežaidžiančių',
#  'santykiuose',
#  'medienos',
#  'keturi',
#  'livintailivintai',
#  'giliųjų',
#  'okupacinė',
#  'vakarus',
#  'apsinuodijo',
#  'keistas',
#  'valsčiui',
#  'eilės',
#  'dieną',
#  'pirco',
#  'kronikoje',
#  'ame',
#  'grandis',
#  'lietuviams',
#  'jono',
#  'pietinius',
#  'profsąjungą',
#  'išlikti',
#  'draustinis',
#  'marvelėje',
#  'naudoja',
#  'visiškai',
#  'stovėjusio',
#  'paminėjimus',
#  'saugosianti',
#  'vientisųjų',
#  'santykį',
#  'hermann',
#  'sutvarkytos',
#  'tikėjimo',
#  'identiteto',
#  'mokyti',
#  'senajame',
#  'jepė',
#  'supertaurė',
#  'sąmokslą',
#  'ginti',
#  'naikinti',
#  'paknio',
#  'užtvankų',
#  'priėjimą',
#  'namus',
#  'orientuoti',
#  'kurio',
#  'departamento',
#  'švietimo',
#  'carai',
#  'plotus',
#  'dykumomis',
#  'paskelbtas',
#  'rudoji',
#  'negiliai',
#  'partijose…',
#  'henri',
#  'pakrantėse',
#  'valdžiusi',
#  'šimtą',
#  'trumpam',
#  'kilo',
#  'putino',
#  'nebūtų',
#  'eišiškių',
#  'pradžių',
#  'paslaptingą',
#  'neįtvirtinta',
#  'smėlėto',
#  'kurecasgrigas',
#  'priimtinas',
#  'karolio',
#  'išsigelbėjo',
#  'displaystyle',
#  'jaunutis',
#  'smulkmeniškai',
#  'konservatorijos',
#  'ishibashi',
#  'kitokioje',
#  'smilgių',
#  'pesticidų',
#  'nesiėmiau',
#  'nuleidžiamas',
#  'pedagoginis',
#  'kiurasao',
#  'mituvos',
#  'lycaena',
#  'likdavo',
#  'skopjėje',
#  'afalinos',
#  'žaisdamas',
#  'sedeikaitė',
#  'perėjas',
#  'tobulinosi',
#  'susitarimas',
#  'krosnos',
#  'madą',
#  'industrijos',
#  'nušlifuotų',
#  'vienintelė',
#  'grigiškėse',
#  'pranskienė',
#  'teisyno',
#  'atlasas',
#  'politinę',
#  'leach',
#  'komitetas',
#  'genties',
#  'esmė',
#  'rajone',
#  'vol',
#  'gelmėse',
#  'aborigenų',
#  'fosforas',
#  'finalinis',
#  'gausius',
#  'didikas',
#  'kuršių',
#  'upelis',
#  'ρ',
#  'antrieji',
#  'vietinio',
#  'būdingas',
#  'kasmet',
#  'varžybose',
#  'šalys',
#  'atstatyti',
#  'kituose',
#  'mačų',
#  'burabajaus',
#  'ponas',
#  'šlaite',
#  'vokietis',
#  'dell’arte',
#  'idėja',
#  'marinho',
#  'down',
#  'vienu',
#  'visai',
#  'mintis',
#  'lakštučių',
#  'reiškiančia',
#  'nereaguoti',
#  'bevor',
#  'pakviesti',
#  'žaidimo',
#  'kolūkiui',
#  'paskelbtos',
#  'perengti',
#  'žemupiuose',
#  'pramoga',
#  'xviii',
#  'ankstesnės',
#  'sustabdyta',
#  'susirėmimas',
#  'benesse',
#  'užsakomuosius',
#  'komuna',
#  'našlė',
#  'athletic',
#  'sudano',
#  'mišučių',
#  'atgyvenusios',
#  'grigas',
#  'vandenys',
#  'veikėja',
#  'inspekcijos',
#  'geologinį',
#  'blinda',
#  'studijas',
#  'aikštelė',
#  'gėláitis',
#  'lygybė',
#  'kvalifikacija',
#  'henmantimotis',
#  'ldk',
#  'paskutiniajam',
#  'našle',
#  'räikkönen',
#  'dvylikos',
#  'geleriui',
#  'nedidelę',
#  'cenzu',
#  'legendinis',
#  'pabėgti',
#  'tremti',
#  'steigėja',
#  'viduramžių',
#  'atidėtąją',
#  'įsivėlė',
#  'klausyklose',
#  'chabarovskas',
#  'baudžiauninkai',
#  'jėga',
#  'pusės',
#  'šeimos',
#  'repnino',
#  'pateikti',
#  'nežinomos',
#  'įsivėlusi',
#  'alebardą',
#  'klubo',
#  'ku',
#  'minimalus',
#  'varezėje',
#  'ck',
#  'varžybos',
#  'pvz',
#  'anksčiau',
#  'visiems',
#  'žemiau',
#  'raudonumą',
#  'yamauchi',
#  'prekybinius',
#  'būdingais',
#  'vandenyno',
#  'daugelio',
#  'parkas',
#  'pasitikėjo',
#  'patalpoje',
#  'dobšinos',
#  'antiknyga',
#  'trinyčių',
#  'vardais',
#  'formavimąsi',
#  'prekiniai',
#  'marija',
#  'platforma',
#  'varšuvą',
#  'lietuvai',
#  'kraštovaizdis',
#  'rankraščiuose',
#  'žvakutes',
#  'terasa',
#  'saviniko',
#  'hedges',
#  'taurė',
#  'vyriausybės',
#  'kelios',
#  'petrosianas',
#  'atidavė',
#  'suorganizavo',
#  'tepraėjo',
#  'žvilgsnį',
#  'bajasas',
#  'reikalavimus',
#  'miškolcas',
#  'būdavo',
#  'masyvų',
#  'būtina',
#  'miesto',
#  'klasių',
#  'turnyre',
#  'nepaliestą',
#  'musulmonai',
#  'du',
#  'pertvarkymai',
#  'jam',
#  'vyriausiasis',
#  'dainavimo',
#  'geležinkelis',
#  'goramaria',
#  'canus',
#  'vienintelis',
#  'formaliai',
#  'takoskyra',
#  'hilzenų',
#  'rydzevskiu',
#  'dirbti',
#  'gėlos',
#  'provincija',
#  'filipiniečių',
#  'jekaterinai',
#  'įžymybės',
#  'ponia',
#  'tarptautinių',
#  'riblis',
#  'monografijos',
#  'įvykis',
#  'hall',
#  'grikštų',
#  'kultūravidurio',
#  'tikisi',
#  'ciklo',
#  'išgaubta',
#  'pasirodę',
#  'nusakantis',
#  'nuosėdos',
#  'alkai',
#  'veikėjų',
#  'demonstraciją',
#  'miestą',
#  'superkompiuteris',
#  'gaigalas',
#  'mirusio',
#  'pritaikymo',
#  'frederick',
#  'karo',
#  'კარწახის',
#  'šiluminės',
#  'francorchamps',
#  'galutinai',
#  'žaidimų',
#  'portug',
#  'bolidus',
#  'juodosios',
#  'žaidėjus',
#  'paukščių',
#  'mitsubishi',
#  'rud',
#  'kalnuotuose',
#  'laboratorijose',
#  'literatūra',
#  'sapackinės',
#  'komercijos',
#  'valentinas',
#  'jaunaisiais',
#  'diodą',
#  'žiūrėjo',
#  'nedatuotaleovigildas',
#  'gimnaziją',
#  'nutarimą',
#  'trepkus',
#  'gyvenanti',
#  'vaikystės',
#  'boksininkas',
#  'kitko',
#  'vembrė',
#  'chemijos',
#  'anglų',
#  'taryba',
#  'kalbą',
#  'kampiljašas',
#  'reformomis',
#  'paberžės',
#  'larseną',
#  'urėdijos',
#  'subrandino',
#  'detektyvinė',
#  'belebekas',
#  'pasiėmė',
#  'lenkai',
#  'nuogulos',
#  'komplektas',
#  'jakovas',
#  'pirmenybės',
#  'ateities',
#  'kilmė',
#  'jais',
#  'induros',
#  'atimame',
#  'masonas',
#  'nauji',
#  'vyravo',
#  'rūpestingas',
#  'eksternu',
#  'pasiekta',
#  'boleslovas',
#  'įskaitant',
#  'salos',
#  'valdžios',
#  'viskonsinas',
#  'atliekami',
#  'būstai',
#  'adjunkto',
#  'apibūdinamas',
#  'tirpsmo',
#  'rezultatu',
#  'univesitetai',
#  'nuomininku',
#  'grupės',
#  'jonas',
#  'žemupys',
#  'archeologas',
#  'žumbaktaso',
#  'išsikrauna',
#  'varliagyviais',
#  'pervadintas',
#  'kiekiai',
#  'penkios',
#  'versmėsskroblaus',
#  'puolėjo',
#  'habilituota',
#  'nusistovėjo',
#  'klimaukos',
#  'ketvirta',
#  'panaikinimas',
#  'gulko',
#  'negalėjo',
#  'pabaltijo',
#  'katalikiškų',
#  'verakrusas',
#  'mokymai',
#  'hitų',
#  'direktoriaus',
#  'piečiau',
#  'naktį',
#  'pruto',
#  'pastebėjo',
#  'vykdoma',
#  'kaimu',
#  'panaikinimo',
#  'piešinius',
#  'kita',
#  'xvii',
#  'luistai',
#  'seniūnija',
#  'iškilusi',
#  'valstybė',
#  'specialistams',
#  'bendraamžių',
#  'moldėje',
#  'uolomis',
#  'alvaradą',
#  'švenčionių',
#  'vi–xv',
#  'įsitvirtintų',
#  'statybas',
#  'aviacijos',
#  'metalo',
#  'potvarkiu',
#  'tarpzoninį',
#  'romanijos',
#  'užminavo',
#  'sinfonica',
#  'apskritą',
#  'diodui',
#  'petrosianui',
#  'kuriam',
#  'utenos',
#  'manė',
#  'dipterocarpus',
#  'mocarto',
#  'protestantiškas',
#  'specifiniai',
#  'suvažiuoja',
#  'kerelis',
#  'lietuvą',
#  'ligoninėje',
#  'matijošaitienė',
#  'pasiekiamas',
#  'sugrįžęs',
#  'institucijų',
#  'žaidėjai',
#  'dešimtojo',
#  'sutinkama',
#  'išleisti',
#  'technikos',
#  'dvišalę',
#  'taika',
#  'ta',
#  'priimti',
#  'daugelį',
#  'pagrindinius',
#  'britaniją',
#  'medaus',
#  'kudirkos',
#  'tamkiūtė',
#  'dėsnio',
#  'paruoštų',
#  'petrui',
#  'dešinėje',
#  'jūra',
#  'melsdavosi',
#  'katalikų',
#  'kazachstanas',
#  'gene',
#  ...}

# %%
freqs = {'is': is_set, 'fr': fr_set, 'sv': sv_set, 'lt': lt_set}

# %% [markdown]
# Определяем язык.

# %%
def predict_language_freqword(text, dic_freqword, langs):
    text_tokens = set(tokenize(text.lower()))
    similar_stat = {}
    
    for lang in langs:
        similar_stat[lang] = len(text_tokens & dic_freqword[lang])

    return max(similar_stat, key=lambda x: similar_stat[x])

# %% [markdown]
# ### Второй метод: частотные символьные n-граммы

# %% [markdown]
# Создадим функцию, которая преобразовывает строку в массив n-грамм заданной длины.

# %%
from itertools import islice, tee

def make_ngrams(text):
    pattern = re.compile('[\.,\-\`\#\?\+\*\^\d\=\~\!\@\$\%\&\(\)\_\—\[\]\{\}\:\;\'\"\/\\\>\<\|„“]')
    text = pattern.sub(' ', text)
    text = re.sub(r'\s+', ' ', text)
    N = 3 # задаем длину n-граммы
    ngrams = zip(*(islice(seq, index, None) for index, seq in enumerate(tee(text, N))))
    ngrams = [''.join(x) for x in ngrams]
    ngrams = [x.strip() for x in ngrams if len(re.findall('\s', x)) == 0] #вычистила "разорванные" пробелами н-граммы
                                                                          #не знаю, насколько это прагматично  
    return ngrams

# %% [markdown]
# Теперь создадим частотные словари n-грамм аналогично первому методу.

# %%
def make_freq_ngrams(lang, wiki_texts):
    ngrams_lang = collections.defaultdict(lambda: 0)
    corpus = wiki_texts[lang]
    for article in corpus:
        for word in make_ngrams(article.replace('\n', '').lower()):
            ngrams_lang[word] += 1
    return set(ngrams_lang.keys())

# %%
is_set_ngs = make_freq_ngrams('is', wiki_texts)
fr_set_ngs = make_freq_ngrams('fr', wiki_texts)
sv_set_ngs = make_freq_ngrams('sv', wiki_texts)
lt_set_ngs = make_freq_ngrams('lt', wiki_texts)

# %%
duplicates_ngrams = set.intersection(is_set_ngs, fr_set_ngs, sv_set_ngs, lt_set_ngs)

# %%
is_set_ngs = is_set_ngs - duplicates_ngrams
fr_set_ngs = fr_set_ngs - duplicates_ngrams
sv_set_ngs = sv_set_ngs - duplicates_ngrams
lt_set_ngs = lt_set_ngs - duplicates_ngrams

# %%
freqs_ngrams = {'is': is_set_ngs, 'fr': fr_set_ngs, 'sv': sv_set_ngs, 'lt': lt_set_ngs}

# %%
def predict_language_freqngrams(text, dic_freqngram, langs):
    text_ngrams = set(make_ngrams(text.lower()))
    similar_stat = {}
    
    for lang in langs:
        similar_stat[lang] = len(text_ngrams & dic_freqngram[lang])

    return max(similar_stat, key=lambda x: similar_stat[x])

# %% [markdown]
# Тестирование.

# %%
text_predictions = {}

for lang in langs: 
    text_predictions[lang] = get_texts_for_lang(lang, 100)
    print(lang, len(text_predictions[lang]))
# Out:
# c:\users\user\appdata\local\programs\python\python35-32\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 184 of the file c:\users\user\appdata\local\programs\python\python35-32\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Skipping page Comté d'Owen
# Skipping page F̧
# Skipping page CEEA
# Skipping page Assemblée de la République
# Skipping page Volonté
# Skipping page Ligne 57
# Skipping page Roy Stuart
# fr 93
# Skipping page Skeið
# Skipping page Sigurður Sigurðarson
# Skipping page Sergíus 3.
# is 97
# Skipping page Beluga Mountain
# Skipping page Hubbs (auktor)
# Skipping page Ämtasjön
# Skipping page La Muneca
# Skipping page Santa Cruz Buena Vista
# Skipping page Sungai Luang
# Skipping page Ferreiras (olika betydelser)
# Skipping page Sungai Kemubu
# Skipping page Waterloo Park
# sv 91
# Skipping page Ustronė
# Skipping page Dubingiai (reikšmės)
# Skipping page Arabija
# Skipping page Litwa
# Skipping page Adomonis
# Skipping page Laužikas
# lt 94

# %%
def test_predictions(text_predictions, langs, dic_freqword, dic_freqngram):
    ngrams = []
    fre = []
    errors_n = []
    errors_f = []
    error_texts = []
    for lang in langs:
        for el in text_predictions[lang]:
            f = predict_language_freqword(el, dic_freqword, langs)
            n = predict_language_freqngrams(el, dic_freqngram, langs)
            ngrams.append(n == lang)
            fre.append(f == lang)
            if n != lang:
                errors_n.append(str(lang) + '-' + str(n))
                error_texts.append(str(lang) + '\n' + el)
            if f != lang:
                errors_f.append(str(lang) + '-' + str(f))
                error_texts.append(str(lang) + '\n' + el)
    return fre, ngrams, errors_n, errors_f, error_texts

# %%
fre, ngrams, errors_n, errors_f, error_texts = test_predictions(text_predictions, langs, freqs, freqs_ngrams)

# %%
False in fre
# Out:
# False

# %%
False in ngrams
# Out:
# True

# %% [markdown]
# Посмотрим, какие два языка перепутал метод нграмм и в каких случаях. Для этого немного изменим функцию test_predictions, чтобы записывалась информация об ошибках.

# %%
errors
# Out:
# ['fr-lt']

# %% [markdown]
# Ошибка в одном тексте: французский определился как литовский методом нграмм. Можно попробовать посмотреть на этот текст.

# %%
print(error_texts[0])
# Out:
# fr
# Liste des villes de Californie du sud par population
# Portail de la Californie

# %% [markdown]
# Текст маленький и не по большей части состоит из "интернациональных" лексем, что логично объясняет ошибку алгоритма.
